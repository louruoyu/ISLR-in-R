# %%
set.seed(100)
x=seq(0,1,0.1)
plot(x,sin(2*pi*x),col="red",type = "l ")
# Out:
# Warning message in plot.xy(xy, type, ...):
# "绘图种类'l '被缩短成第一个字符"
# plot without title

# %%
n <- 10
X <- runif(n,0,1)
y0 <- sin(2*pi*X)
y <- y0 + rnorm(n,0,1)
plot(x,sin(2*pi*x),col="red",type="l",ylim=c(-2,2))
points(X,y)
# Out:
# plot without title

# %%
install.packages("linReg.R")
# Out:
# Installing package into 'C:/Users/风雨未留痕/Documents/R/win-library/4.0'
# (as 'lib' is unspecified)
#
# Warning message:
# "package 'linReg.R' is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages"
